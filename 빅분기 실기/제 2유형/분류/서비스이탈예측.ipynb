# %% [markdown]
# # 서비스 이탈 예측

# %% [markdown]
# 데이터 설명 : 고객의 신상정보 데이터를 통한 회사 서비스 이탈 예측 (종속변수 : Exited)
#
# x_train :
# [https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv](https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv)
#
# y_train :
# [https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv](https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv)
#
# x_test :
# [https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv](https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv)
#
# x_label(평가용) :
# [https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_test.csv](https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_test.csv)
#
# 데이터 출처 :
# [https://www.kaggle.com/shubh0799/churn-modelling](https://www.kaggle.com/shubh0799/churn-modelling)
#
# 에서 변형

# %%
import time , datetime
start = time.time()

import pandas as pd
import numpy as np
import warnings
from sklearn.preprocessing import MinMaxScaler, StandardScaler
Scaler_m = MinMaxScaler()
Scaler_s = StandardScaler()
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
from sklearn.metrics import roc_auc_score

def scaler_m(df):
    num = df.select_dtypes(include='number').columns
    for col in num:
        df[col] = Scaler_m.fit_transform(df[[col]])
    return df
def scaler_s(df):
    num = df.select_dtypes(include='number').columns
    for col in num:
        df[col] = Scaler_s.fit_transform(df[[col]])
    return df
def le(df):
    obj = df.select_dtypes(include='object').columns
    for col in obj:
        df[col]=LE.fit_transform(df[col])
    return df

X_train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv')
X_test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv')
# print(X_train.head())
# print(y_train.head())
# print(X_train.isnull().sum())
# print(X_test.isnull().sum())
df = pd.merge(X_train,y_train, on = 'CustomerId')
X = df.drop(['CustomerId','Exited'],axis=1)
y = df.Exited
X_t = X_test.drop('CustomerId',axis=1)

# print(X.info())
X = le(X)
X_t = le(X_t)
X_s = scaler_s(X)
X_ts= scaler_s(X_t)
# print(df.Exited.value_counts()) 1이 이탈이라고 본다.

roc_list= []
for a in range(50):
    X_tr_s, X_val_s, y_tr_s, y_val_s = train_test_split(X_s,y,test_size=0.2, random_state=a)
    rfc.fit(X_tr_s,y_tr_s)
    pred_y_val = rfc.predict_proba(X_val_s)
    roc= roc_auc_score(y_val_s,pred_y_val[:,1])
    roc_list.append((a,roc))
                    
roc_list.sort()
print(roc_list[0])

time_result = str(datetime.timedelta(seconds=time.time()-start)).split(".")
print("소요 시간 : ",time_result[0]) 
# print(roc_auc_score(y_val_s,pred_y_val[:,1]))
# y_pred = rfc.predict_proba(X_ts)

# y_real = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_test.csv')
# print(roc_auc_score(y_real.Exited,y_pred[:,1]))
# Out:
# (0, 0.8499498623084291)
# 소요 시간 :  0:00:43

# %% [markdown]
# 1분이 안넘는다. randomstate= 0 으로 두고 제출하기

# %%
X_m = scaler_m(X)
X_tm= scaler_m(X_t)

X_tr_m, X_val_m, y_tr_m, y_val_m = train_test_split(X_m,y,test_size=0.2, random_state=48)

rfc.fit(X_tr_m,y_tr_m)
pred_y_val = rfc.predict_proba(X_val_m)
print(roc_auc_score(y_val_s,pred_y_val[:,1]))
y_pred = rfc.predict_proba(X_tm)
y_real = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_test.csv')
print(roc_auc_score(y_real.Exited,y_pred[:,1]))
# Out:
# 0.8403997746697457
# 0.8486586472580343

# %%
roc_list = []
for a in range(50,100):
    X_tr_s, X_val_s, y_tr_s, y_val_s = train_test_split(X_s,y,test_size=0.2, random_state=a)
    rfc.fit(X_tr_s,y_tr_s)
    pred_y_val = rfc.predict_proba(X_val_s)
    roc = roc_auc_score(y_val_s,pred_y_val[:,1])
    roc_list.append((a,roc))
roc_list.sort()
print(roc_list[0])
# Out:
# (50, 0.8473908797554348)

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

pd.set_option('max_columns',None)
pd.set_option('max_rows',None)

# %%
X_train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/X_train.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/y_train.csv')
X_test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/X_test.csv')
y_test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/y_test.csv')
x_test =X_test.copy()

print(X_train.head())
# Out:
#    carID     brand      model  year transmission  mileage fuelType    tax  \
# 0  13207    hyundi   Santa Fe  2019    Semi-Auto     4223   Diesel  145.0
# 1  17314  vauxhall        GTC  2015       Manual    47870   Diesel  125.0
# 2  12342      audi        RS4  2019    Automatic     5151   Petrol  145.0
# 3  13426        vw   Scirocco  2016    Automatic    20423   Diesel   30.0
# 4  16004     skoda      Scala  2020    Semi-Auto     3569   Petrol  145.0
#
#     mpg  engineSize
# 0  39.8         2.2
# 1  60.1         2.0
# 2  29.1         2.9
# 3  57.6         2.0
# 4  47.1         1.0

# %% [markdown]
# ## 훈련데이터 가공 및 모델 훈련

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carID         4960 non-null   int64
#  1   brand         4960 non-null   object
#  2   model         4960 non-null   object
#  3   year          4960 non-null   int64
#  4   transmission  4960 non-null   object
#  5   mileage       4960 non-null   int64
#  6   fuelType      4960 non-null   object
#  7   tax           4960 non-null   float64
#  8   mpg           4960 non-null   float64
#  9   engineSize    4960 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 387.6+ KB

# %%
print(y_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   carID   4960 non-null   int64
#  1   price   4960 non-null   int64
# dtypes: int64(2)
# memory usage: 77.6 KB
# None

# %%
df = pd.merge(X_train, y_train, on = 'carID')
df.head(3)
# Out:
#    carID     brand      model  year transmission  mileage fuelType    tax  \
# 0  13207    hyundi   Santa Fe  2019    Semi-Auto     4223   Diesel  145.0
# 1  17314  vauxhall        GTC  2015       Manual    47870   Diesel  125.0
# 2  12342      audi        RS4  2019    Automatic     5151   Petrol  145.0
#
#     mpg  engineSize  price
# 0  39.8         2.2  31995
# 1  60.1         2.0   7700
# 2  29.1         2.9  58990

# %%
len(df.brand.value_counts())
# Out:
# 9

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
str_features = ['brand' , 'model', 'transmission', 'fuelType']
for feature in str_features:
    df[feature] = le.fit_transform(df[[feature]])
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4960 entries, 0 to 4959
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carID         4960 non-null   int64
#  1   brand         4960 non-null   int32
#  2   model         4960 non-null   int32
#  3   year          4960 non-null   int64
#  4   transmission  4960 non-null   int32
#  5   mileage       4960 non-null   int64
#  6   fuelType      4960 non-null   int32
#  7   tax           4960 non-null   float64
#  8   mpg           4960 non-null   float64
#  9   engineSize    4960 non-null   float64
#  10  price         4960 non-null   int64
# dtypes: float64(3), int32(4), int64(4)
# memory usage: 387.5 KB

# %%
df.head(3)
# Out:
#    carID  brand  model  year  transmission  mileage  fuelType    tax   mpg  \
# 0  13207      3     69  2019             3     4223         0  145.0  39.8
# 1  17314      7     30  2015             1    47870         0  125.0  60.1
# 2  12342      0     58  2019             0     5151         4  145.0  29.1
#
#    engineSize  price
# 0         2.2  31995
# 1         2.0   7700
# 2         2.9  58990

# %%
df.describe()
# Out:
#               carID        brand        model         year  transmission  \
# count   4960.000000  4960.000000  4960.000000  4960.000000   4960.000000
# mean   15832.446169     3.975605    43.787097  2016.737903      1.210282
# std     2206.717006     2.530557    26.192222     2.884035      1.174928
# min    12002.000000     0.000000     0.000000  1997.000000      0.000000
# 25%    13929.250000     2.000000    21.000000  2016.000000      0.000000
# 50%    15840.000000     4.000000    42.000000  2017.000000      1.000000
# 75%    17765.750000     6.000000    69.000000  2019.000000      3.000000
# max    19629.000000     8.000000    89.000000  2020.000000      3.000000
#
#              mileage     fuelType          tax          mpg   engineSize  \
# count    4960.000000  4960.000000  4960.000000  4960.000000  4960.000000
# mean    24956.286895     1.506855   152.332661    50.370766     2.124375
# std     24443.333662     1.894248    82.403844    35.746505     0.789368
# ...

# %%
df.drop('carID', axis=1, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(df.drop('price',axis=1))
X = scaled_df
y = df['price']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train,y_train)
pred_val1 = lr.predict(X_test)
print(lr.score(X_train,y_train))
print(lr.score(X_test,y_test))
# Out:
# 0.6857543624538822
# 0.6640223117487322

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

xgb = XGBRegressor(n_jobs=-1, random_state=42)
params = {'n_estimators':[300],'max_depth':[2,5],'learning_rate':[0.01]}
grid = GridSearchCV(xgb, param_grid= params, n_jobs=-1,cv=4,return_train_score=True)

grid.fit(X_train,y_train)

best_grid=grid.best_estimator_
pred_val2 = best_grid.predict(X_test)

# %% [markdown]
# !pip install xgboost

# %%
print(pred_val1,pred_val2)
# Out:
# [19464.48987433 10799.34535312 30579.21707855 ... 27919.65220369
#  24468.86758568 33714.41478855] [18140.1   15109.684 21100.164 ... 14914.669 28704.834 25104.234]

# %%
print(len(pred_val1),len(pred_val2),len(y_test))
# Out:
# 1488 1488 1488

# %%
from sklearn.metrics import r2_score, mean_squared_error

mse1 = mean_squared_error(y_test,pred_val1)
mse2 = mean_squared_error(y_test,pred_val2)
r2_1 = r2_score(y_test,pred_val1)
r2_2 = r2_score(y_test,pred_val2)

print(mse1, mse2)
print(r2_1,r2_2)
# Out:
# 92375043.87018281 25472731.75833866
# 0.6640223117487322 0.907353012555659

# %% [markdown]
# ## 테스터데이터로 확인

# %%
x_test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/X_test.csv')

# %%
x_label = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/y_test.csv')

# %%
x_label
# Out:
#       carID   price
# 0     12000   38000
# 1     12001   23495
# 2     12004   59999
# 3     12013   16713
# 4     12017   46000
# 5     12019   24995
# 6     12020   15699
# 7     12024   20498
# 8     12027   23995
# 9     12028   34995
# 10    12029   32888
# 11    12034   29990
# 12    12040   49500
# 13    12041   34999
# 14    12042   10990
# 15    12043   33000
# 16    12046   44980
# 17    12047   28985
# 18    12048    2750
# 19    12049    6480
# 20    12052   27500
# 21    12054   23490
# 22    12056   26498
# 23    12060   32023
# 24    12064   55649
# 25    12069   32995
# 26    12071   89900
# 27    12073   30000
# 28    12076   30990
# 29    12081   12000
# 30    12082   18737
# 31    12083   20995
# 32    12088    8769
# 33    12091   19990
# 34    12095   19399
# 35    12096   18991
# 36    12100   26995
# 37    12102   21495
# 38    12103  104400
# 39    12116   32000
# 40    12119   67400
# 41    12122    8420
# 42    12129   12295
# 43    12133   29000
# ...

# %%
x_test_drop=x_test.drop('carID',axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

str_features = ['brand' , 'model', 'transmission', 'fuelType']
for feature in str_features:
    x_test_drop[feature] = le.fit_transform(x_test_drop[[feature]])
    
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaled_xtest = scaler.fit_transform(x_test_drop)

#pred = best_grid.predict(x_test_drop)

print(pred)
# Out:
# [54995.496 54995.496 54995.496 ... 55227.188 55015.34  54995.496]

# %%
df2=pd.DataFrame({'carID':x_test.carID,'real':x_label.price,'prediction':pred})

# %%
df2.head()
# Out:
#    carID   real    prediction
# 0  12000  38000  54995.496094
# 1  12001  23495  54995.496094
# 2  12004  59999  54995.496094
# 3  12013  16713  55227.187500
# 4  12017  46000  52694.515625

# %%
x_test.head(3)
# Out:
#    brand  model  year  transmission  mileage  fuelType    tax   mpg  \
# 0      4     28  2017             0    12046         0  150.0  37.2
# 1      8      6  2017             0    37683         0  260.0  36.2
# 2      4     28  2019             0    10000         0  145.0  34.0
#
#    engineSize
# 0         3.0
# 1         3.0
# 2         3.0
